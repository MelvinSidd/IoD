# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 2.1.2
# # *Exploring Data*

# %% [markdown]
# ## Part 1: Continuous and Categorical Data

# %% [markdown]
# When we explore a dataset we usually produce textual and graphical output together, starting with a high-level overview of the data and gradually drilling down into the individual features and relationships between them.

# %% [markdown]
# Our most important libraries for this task are:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# Cause plots to be displayed in the notebook:
# %pylab inline
# %matplotlib inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
# Override default figure sizing:
pylab.rcParams['figure.figsize'] = (10, 6)
sns.set(color_codes = True)

# %% [markdown]
# ## Data Profiling
#
# We actually start profiling the data when we first load it and check for input errors, as in the last lab. Once we have a DataFrame we can work with, however, things start getting more interesting.

# %% [markdown]
# **Load the file "bikeshare.csv" into a DataFrame named `bikes`, and check that it was loaded properly:**

# %%
#ANSWER:
bikedf=pd.read_csv(r"D:\Download\DataScience\Files\Week040923\bikeshare.csv")
bikedf.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# We may want our program to capture particular features of the dataset into variables, but if we just want to get a feel for the data it is easier to use a higher-level Pandas method like `describe()`:
#
# **Use `describe` to get the description of datasets.**

# %%
#ANSWER:
bikedf.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# std        0.167165      2.005771      0.465431      0.639357      0.192556
# min        0.000000      0.000000      0.000000      1.000000      0.020000
# 25%        0.000000      1.000000      0.000000      1.000000      0.340000
# 50%        0.000000      3.000000      1.000000      1.000000      0.500000
# 75%        0.000000      5.000000      1.000000      2.000000      0.660000
# max        1.000000      6.000000      1.000000      4.000000      1.000000
#
#               atemp           hum     windspeed        casual    registered  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.475775      0.627229      0.190098     35.676218    153.786869
# std        0.171850      0.192930      0.122340     49.305030    151.357286
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.333300      0.480000      0.104500      4.000000     34.000000
# 50%        0.484800      0.630000      0.194000     17.000000    115.000000
# 75%        0.621200      0.780000      0.253700     48.000000    220.000000
# max        1.000000      1.000000      0.850700    367.000000    886.000000
#
#                 cnt
# count  17379.000000
# mean     189.463088
# std      181.387599
# min        1.000000
# 25%       40.000000
# 50%      142.000000
# 75%      281.000000
# max      977.000000

# %% [markdown]
# ### Continuous Data

# %% [markdown]
# We may have to do a lot of work before we can produce presentable graphics, but we can start creating simple visualisations as soon as we have a DataFrame.
#
# We usually start charting variables one-by-one (although when several have the same range it may be preferable to overlay them, using a different colour or symbol for each).

# %% [markdown]
# **Use the `scatter` method of Pandas to create a scatter plot of `windspeed`, `temp`:**

# %%
#ANSWER
plt.scatter(bikedf['windspeed'], bikedf['temp'])
plt.xlabel('windspeed')
plt.ylabel('temp')
# Out:
# Text(0, 0.5, 'temp')

# %% [markdown]
# **The `scatter` method has various parameters for controlling the appearance of the chart. Experiment with `s` , `linewidths`, and `alpha` below:**

# %%
#ANSWER
plt.scatter(bikedf['windspeed'], bikedf['temp'], s=3, linewidths=0.8, alpha=0.5)
plt.xlabel('windspeed')
plt.ylabel('temp')
# Out:
# Text(0, 0.5, 'temp')

# %% [markdown]
# The scatterplot shows us the raw data. Our next step is usually to see how it is distributed, which is what the histogram is for:
#
# > A histogram is used for continuous data, where the bins represent ranges of data, while a bar chart is a plot of categorical variables. <sup>[1](#histfootnote)</sup>
#
# - **Identify continuous variables**
# - **Create histogram for those variables**

# %%
#ANSWER
bikedf_continuous = bikedf.select_dtypes(include=['float64'])
bikedf_continuous
# Out:
#        temp   atemp   hum  windspeed
# 0      0.24  0.2879  0.81     0.0000
# 1      0.22  0.2727  0.80     0.0000
# 2      0.22  0.2727  0.80     0.0000
# 3      0.24  0.2879  0.75     0.0000
# 4      0.24  0.2879  0.75     0.0000
# ...     ...     ...   ...        ...
# 17374  0.26  0.2576  0.60     0.1642
# 17375  0.26  0.2576  0.60     0.1642
# 17376  0.26  0.2576  0.60     0.1642
# 17377  0.26  0.2727  0.56     0.1343
# 17378  0.26  0.2727  0.65     0.1343
#
# [17379 rows x 4 columns]

# %%
# nrows, ncols = 2, 2
# fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(12, 8))
# axes = axes.flatten()

# for i, column in enumerate(bikedf_continuous.columns):
#     ax = axes[i]
#     ax.hist(bikedf_continuous[column], bins=10, color='skyblue', alpha=0.7)
#     ax.set_title(column)
#     ax.set_xlabel('Value')
#     ax.set_ylabel('Frequency')

# # Adjust layout
# plt.tight_layout()

for column in bikedf_continuous.columns:
    plt.hist(bikedf_continuous[column], bins=10, alpha=0.5)

# %% [markdown]
# What do the horizontal and vertical axes represent?

# %% [markdown]
# #### ANSWER:
#     horiz = magnitude of `atemp`, apparently normalised to [0, 1], discretised into bins of width 0.1;
#     vertical = counts of samples in each bin.

# %% [markdown]
# *NOTE: Samples in a given bin are greater than the axis value of its left side and less than or equal to the axis value of its right side. (The left-most bin is an exception: it represents greater than or equal to.)*

# %% [markdown]
# The box-and-whisker plot provides a compact view of the major percentiles of the distribution:
#
# **Make a box and whisker plot for the column ``atemp``.**
#
# > The box extends from the lower to
# upper quartile values of the data, with a line at the median. The whiskers extend from the box to show the range of the data.  Flier points are those past the end of the whiskers.

# %%
#ANSWER
sns.boxplot(bikedf['atemp'])
# Out:
# <Axes: >

# %% [markdown]
# This kind of plot really shines when we want to show several distributions at once (as long as they have compatible ranges).
#
# **Plot `atemp` and `windspeed` together. Change labels accordingly.**

# %%
#ANSWER
data_to_plot = [bikedf['atemp'], bikedf['windspeed']]
sns.boxplot(data_to_plot)
plt.xlabel('columns')
plt.ylabel('values')
plt.xticks([0,1], ['atemp', 'windspeed'])
plt.title('atemp and windspeed')
plt.show()

# %% [markdown]
# ### Classified Data
#
# Samples may represent different classes according to one or more categorical variables. Sometimes our goal is to discover these classes, or to train a classification model from samples that have been manually classified.

# %% [markdown]
# Here, the famous "Iris" dataset gets loaded from the UCI repository:

# %%
import urllib

# get Iris dataset from UCI Machine Learning Repository:
url = "http://goo.gl/HppjFh"
raw_data = urllib.request.urlopen(url)

# load the CSV file:
iris_data = pd.read_csv(raw_data, delimiter = ",",
                        names = ('sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species'))

# %% [markdown]
# Note that the column names were overridden by the `names` argument of the Pandas `read.csv` method. This requires prior knowledge of the dataset, which we would normally get from a data dictionary (although sometimes we just have to figure it out for ourselves).

# %% [markdown]
# **Print the first few rows of this DataFrame:**

# %%
#ANSWER
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# In this dataset, `species` has several possible values (representing the classes of the samples).
#
# **Find out distinct number of `species` and number of sample for each `species` in this dataset.**

# %%
#ANSWER
iris_data['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %% [markdown]
# We often need to capture the number of classes in code. We can do this with a variation on the above. Try this below:

# %%
#ANSWER
species_classes = iris_data['species'].unique()
len(species_classes)
# Out:
# 3

# %% [markdown]
# We often need to calculate aggregate values within subgroups of the dataset. The Pandas DataFrame method for this is `groupby`.
#
# **Apply the `groupby` method to get `mean` of `sepal_length` and `sepal_width` for the above dataset.**

# %%
#ANSWER
grouped = iris_data.groupby('species')
grouped[['sepal_length', 'sepal_width']].mean()
# Out:
#                  sepal_length  sepal_width
# species
# Iris-setosa             5.006        3.418
# Iris-versicolor         5.936        2.770
# Iris-virginica          6.588        2.974

# %% [markdown]
# The Pandas `plot` method provides a quick way to produce a scatter plot.
#
# **Draw a Scatterplot showing sepal width and length using the Pandas `plot` method.**

# %%
#ANSWER
plt.plot(iris_data['sepal_width'], iris_data['sepal_length'], marker='.', linestyle='none')

# %% [markdown]
# **Draw a Barplot showing sepal width and length using the Pandas plot method.**

# %%
#ANSWER
sns.barplot(x=iris_data['sepal_width'], y=iris_data['sepal_length'])
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %% [markdown]
# Draw a Scatterplot showing sepal width and length using the Pandas plot method.
#
# **[BONUS] Set `title`, `xlabel`, `ylabel` to the plot**

# %%
#ANSWER
plt.scatter(iris_data['sepal_width'], iris_data['sepal_length'])
plt.title('sepal width and sepal length')
plt.xlabel('sepal width')
plt.ylabel('sepal ')
# Out:
# Text(0, 0.5, 'sepal length')

# %% [markdown]
# In this dataset we have also `petal_width`, `petal_length`.
#
# **Try to draw Scatterplot using these variables.**

# %%
#ANSWER
plt.scatter(iris_data['petal_width'], iris_data['petal_length'])
plt.title('petal_width and petal_length')
plt.xlabel('petal width')
plt.ylabel('petal length')
# Out:
# Text(0, 0.5, 'petal length')

# %% [markdown]
# In this case, we already have different species, so we can colour the points accordingly. This is easy to do using the Seaborn library. Try using `lmplot` of seaborn library and use the parameter `hue` and `fit_reg = False`.
#
# **Draw a Scatterplot showing sepal width and length.**

# %%
# ANSWER
# Draw a Scatterplot showing sepal width and length:
sns.lmplot(data=iris_data, x='sepal_width', y='sepal_length', hue='species', fit_reg = False)

# %% [markdown]
# **[BONUS] Draw a Scatterplot showing sepal width and length. Without using seaborn.**

# %%
# ANSWER
plt.scatter(iris_data['sepal_width'], iris_data['sepal_length'])

# %% [markdown]
# To find out why this function is called `lmplot`, try it again with `fit_reg` = True:
#
# **Draw a Scatterplot showing sepal width and length:**

# %%
# ANSWER
# Draw a Scatterplot showing sepal width and length:
sns.lmplot(data=iris_data, x='sepal_width', y='sepal_length', hue='species', fit_reg = True)

# %% [markdown]
# The Seaborn `jointplot` function charts a correlation along with both distributions:
#
# **Draw a jointplot showing sepal width and length:**

# %%
# ANSWER
sns.jointplot(iris_data)

# %% [markdown]
# When we want to see all the correlations at once, we can use `pairplot`:
#
# **Draw a `pairplot` of the dataset:**

# %%
# ANSWER
sns.pairplot(iris_data)

# %% [markdown]
# And, if the classes are known, we can apply colour using the `hue` parameter. Try this below:

# %%
# ANSWER
sns.pairplot(iris_data, hue='species')

# %% [markdown]
# Note that this gave us class-based distributions instead of an overall histogram, as well.

# %% [markdown]
# When we want to see numerical values of the correlations, the Pandas `corr` method provides a table of pair-wise correlations between the features in the DataFrame:

# %%
# ANSWER

# %%
iris_data.corr()
# Out:
# C:\Users\GGPC\AppData\Local\Temp\ipykernel_3304\514728938.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris_data.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %% [markdown]
# ### High-Level Data Profiling Libraries

# %% [markdown]
# We need to master the basic data profiling functions because we will by using them frequently, for exploring data and answering ad hoc questions. In a production solution, we may need to incorporate specific data profiling code into our script so that we can automate data cleaning. However, when we just want to examine the data interactively before we start modelling, it is easier to use a high-level library like the following:
#
# > pip install sweetviz

# %%
# !pip install sweetviz
# Out:
# Collecting sweetviz
#   Obtaining dependency information for sweetviz from https://files.pythonhosted.org/packages/7b/d7/b83a6a5548f6fd028c18e198f116e0be641c0db72cc12b0d6ddb836d0fa4/sweetviz-2.2.1-py3-none-any.whl.metadata
#   Downloading sweetviz-2.2.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in d:\program\anaconda\lib\site-packages (from sweetviz) (1.5.3)
# Requirement already satisfied: numpy>=1.16.0 in d:\program\anaconda\lib\site-packages (from sweetviz) (1.23.5)
# Requirement already satisfied: matplotlib>=3.1.3 in d:\program\anaconda\lib\site-packages (from sweetviz) (3.7.1)
# Requirement already satisfied: tqdm>=4.43.0 in d:\program\anaconda\lib\site-packages (from sweetviz) (4.65.0)
# Requirement already satisfied: scipy>=1.3.2 in d:\program\anaconda\lib\site-packages (from sweetviz) (1.10.1)
# Requirement already satisfied: jinja2>=2.11.1 in d:\program\anaconda\lib\site-packages (from sweetviz) (3.1.2)
# Collecting importlib-resources>=1.2.0 (from sweetviz)
#   Obtaining dependency information for importlib-resources>=1.2.0 from https://files.pythonhosted.org/packages/25/d4/592f53ce2f8dde8be5720851bd0ab71cc2e76c55978e4163ef1ab7e389bb/importlib_resources-6.0.1-py3-none-any.whl.metadata
#   Downloading importlib_resources-6.0.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\program\anaconda\lib\site-packages (from jinja2>=2.11.1->sweetviz) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\program\anaconda\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in d:\program\anaconda\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\program\anaconda\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\program\anaconda\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\program\anaconda\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\program\anaconda\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\program\anaconda\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\program\anaconda\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\program\anaconda\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2022.7)
# Requirement already satisfied: colorama in d:\program\anaconda\lib\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.6)
# Requirement already satisfied: six>=1.5 in d:\program\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)
# Downloading sweetviz-2.2.1-py3-none-any.whl (15.1 MB)
#    ---------------------------------------- 0.0/15.1 MB ? eta -:--:--
#    ---- ----------------------------------- 1.7/15.1 MB 35.7 MB/s eta 0:00:01
#    --------- ------------------------------ 3.5/15.1 MB 37.6 MB/s eta 0:00:01
#    -------------- ------------------------- 5.4/15.1 MB 38.5 MB/s eta 0:00:01
#    ------------------- -------------------- 7.3/15.1 MB 38.8 MB/s eta 0:00:01
#    ------------------------ --------------- 9.3/15.1 MB 39.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.2/15.1 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.2/15.1 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------  15.1/15.1 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------  15.1/15.1 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------- 15.1/15.1 MB 34.4 MB/s eta 0:00:00
# Downloading importlib_resources-6.0.1-py3-none-any.whl (34 kB)
# Installing collected packages: importlib-resources, sweetviz
# Successfully installed importlib-resources-6.0.1 sweetviz-2.2.1

# %%
# ANSWER
import pandas as pd
import sweetviz as sv
df = pd.read_csv(r"D:\Download\DataScience\Files\Week040923\090923MiniProject\Meteorite_Landings.csv", parse_dates = ['year'], encoding = 'UTF-8')
df.head(10)
# Out:
#                   name   id nametype     recclass  mass (g)  fall  \
# 0               Aachen    1    Valid           L5      21.0  Fell
# 1               Aarhus    2    Valid           H6     720.0  Fell
# 2                 Abee    6    Valid          EH4  107000.0  Fell
# 3             Acapulco   10    Valid  Acapulcoite    1914.0  Fell
# 4              Achiras  370    Valid           L6     780.0  Fell
# 5             Adhi Kot  379    Valid          EH4    4239.0  Fell
# 6  Adzhi-Bogdo (stone)  390    Valid        LL3-6     910.0  Fell
# 7                 Agen  392    Valid           H5   30000.0  Fell
# 8               Aguada  398    Valid           L6    1620.0  Fell
# 9        Aguila Blanca  417    Valid            L    1440.0  Fell
#
#                      year    reclat    reclong               GeoLocation
# 0  01/01/1880 12:00:00 AM  50.77500    6.08333     (50.775000, 6.083330)
# 1  01/01/1951 12:00:00 AM  56.18333   10.23333    (56.183330, 10.233330)
# 2  01/01/1952 12:00:00 AM  54.21667 -113.00000  (54.216670, -113.000000)
# 3  01/01/1976 12:00:00 AM  16.88333  -99.90000   (16.883330, -99.900000)
# 4  01/01/1902 12:00:00 AM -33.16667  -64.95000  (-33.166670, -64.950000)
# 5  01/01/1919 12:00:00 AM  32.10000   71.80000    (32.100000, 71.800000)
# 6  01/01/1949 12:00:00 AM  44.83333   95.16667    (44.833330, 95.166670)
# 7  01/01/1814 12:00:00 AM  44.21667    0.61667     (44.216670, 0.616670)
# 8  01/01/1930 12:00:00 AM -31.60000  -65.23333  (-31.600000, -65.233330)
# 9  01/01/1920 12:00:00 AM -30.86667  -64.55000  (-30.866670, -64.550000)

# %% [markdown]
# Use `analyze` and `show_html` of `sweetviz` to get an overview of the dataset.

# %%
# ANSWER
meteor_report = sv.analyze(df)
meteor_report.show_html()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ## Part 2: Time Series and Geospatial Data

# %% [markdown]
# ## Time Series
#
# A time series is basically a series or a data frame with a time-based index column. Working with time series introduces a lot of challenges and possibilities, but most tasks are catered for by the standard libraries in Python.

# %% [markdown]
# Here is a history of air passenger counts by month, loaded into an ordinary DataFrame:

# %%
airpass = pd.read_csv(r'D:\Download\DataScience\Files\Week040923\090923MiniProject\AirPassengers.csv')
airpass.head()
# Out:
#   TravelDate  Passengers
# 0   1/1/1949         112
# 1   2/1/1949         118
# 2   3/1/1949         132
# 3   4/1/1949         129
# 4   5/1/1949         121

# %%
airpass.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TravelDate  144 non-null    object
#  1   Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %% [markdown]
# Before going any further, the `TravelDate` column needs to be converted to the `datetime` type.

# %%
# ANSWER
airpass['TravelDate'] = pd.to_datetime(airpass['TravelDate'])
airpass
# Out:
#     TravelDate  Passengers
# 0   1949-01-01         112
# 1   1949-02-01         118
# 2   1949-03-01         132
# 3   1949-04-01         129
# 4   1949-05-01         121
# ..         ...         ...
# 139 1960-08-01         606
# 140 1960-09-01         508
# 141 1960-10-01         461
# 142 1960-11-01         390
# 143 1960-12-01         432
#
# [144 rows x 2 columns]

# %% [markdown]
# Set `TravelDate` as index

# %%
# ANSWER
airpass.set_index(airpass['TravelDate'], inplace=True)
airpass.drop(columns=['TravelDate'], inplace=True)

# %% [markdown]
# Now, Pandas knows that the first column of this DataFrame is a datetime index, so it only shows one column of data:
#
# Use `head` to check.

# %%
# ANSWER
airpass.head()
# Out:
#             Passengers
# TravelDate
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %% [markdown]
# Here's how to see the values of the index:

# %%
airpass.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='TravelDate', length=144, freq=None)

# %% [markdown]
# If we had multiple data columns but we only wanted to work with a time series of one of them, we could pull that column into a 1D time series:

# %%
ts = airpass['Passengers']

# %% [markdown]
# We use the datetime index exactly like a row number index:

# %%
print(ts['1949-01-01'])
# Out:
# 112

# %% [markdown]
# Or, we can refer to the row by its datetime equivalent:

# %%
from datetime import datetime
print(ts[datetime(1949,1,1)])
# Out:
# 112

# %% [markdown]
# Happily, Pandas makes it easy to slice data at a courser grain. We can refer to a whole year of data by omitting the month and day form the index:

# %%
print(ts['1949'])
# Out:
# TravelDate
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
# 1949-06-01    135
# 1949-07-01    148
# 1949-08-01    148
# 1949-09-01    136
# 1949-10-01    119
# 1949-11-01    104
# 1949-12-01    118
# Name: Passengers, dtype: int64

# %% [markdown]
# The most basic way to plot a time series is to let Pandas apply the default:

# %%
ts.plot();

# %% [markdown]
# ## Geospatial Data
#
# Geospatial data is map-based (although what constitutes a "map" can go beyond the familiar). Ultimately, geographic data  occurs either in bitmap (raster) form or vector (resizeable polygons). It is not unusual for the two kinds of data to be used together.
#
# Because borders are often complex, following river courses, mountain ranges, and so on, the files that describe their geometries can be large. To reduce file sizes and image rendering times, we prefer to work with polygons that are no more detailed than the maximum resolution we need for our task. For this reason, geospatial files are often available at several different resolutions.

# %% [markdown]
# There are several popular options for working with maps in Python. We will use folium for its breadth and its use of open-source data.

# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.14.0-py2.py3-none-any.whl (102 kB)
#      ---------------------------------------- 0.0/102.3 kB ? eta -:--:--
#      ---------------------------------------- 102.3/102.3 kB ? eta 0:00:00
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.6.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2>=2.9 in d:\program\anaconda\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in d:\program\anaconda\lib\site-packages (from folium) (1.23.5)
# Requirement already satisfied: requests in d:\program\anaconda\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\program\anaconda\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\program\anaconda\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\program\anaconda\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\program\anaconda\lib\site-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\program\anaconda\lib\site-packages (from requests->folium) (2023.7.22)
# Installing collected packages: branca, folium
# Successfully installed branca-0.6.0 folium-0.14.0

# %%
import folium

# %%
# Read SF Incidents data
crime_csv = r'D:\Download\DataScience\Files\Week040923\090923MiniProject\SFPD_Incidents-Current_Year_2015.csv'
crimedf=pd.read_csv(crime_csv)
crimedf.head()
# Out:
#    IncidntNum      Category                         Descript DayOfWeek  \
# 0   150827188  NON-CRIMINAL     AIDED CASE, MENTAL DISTURBED    Sunday
# 1   150827213       ASSAULT      INFLICT INJURY ON COHABITEE    Sunday
# 2   150827213       ASSAULT  ATTEMPTED HOMICIDE WITH A KNIFE    Sunday
# 3   150827213       ASSAULT           CHILD ABUSE (PHYSICAL)    Sunday
# 4   150827213       ASSAULT              MAYHEM WITH A KNIFE    Sunday
#
#          Date   Time PdDistrict      Resolution                   Address  \
# 0  09/20/2015  23:54   RICHMOND       UNFOUNDED  3000 Block of CLEMENT ST
# 1  09/20/2015  23:45  INGLESIDE  ARREST, BOOKED     100 Block of LOEHR ST
# 2  09/20/2015  23:45  INGLESIDE  ARREST, BOOKED     100 Block of LOEHR ST
# 3  09/20/2015  23:45  INGLESIDE  ARREST, BOOKED     100 Block of LOEHR ST
# 4  09/20/2015  23:45  INGLESIDE  ARREST, BOOKED     100 Block of LOEHR ST
#
#             X          Y                               Location
# 0 -122.491851  37.781756  (37.7817557255921, -122.491851328976)
# 1 -122.413676  37.712617  (37.7126165766239, -122.413676487435)
# 2 -122.413676  37.712617  (37.7126165766239, -122.413676487435)
# 3 -122.413676  37.712617  (37.7126165766239, -122.413676487435)
# 4 -122.413676  37.712617  (37.7126165766239, -122.413676487435)

# %% [markdown]
# Convert `Date` Column to DateTime and set as index

# %%
# ANSWER
crimedf['Date'] = pd.to_datetime(crimedf['Date'])
print(len(crimedf))
crimedf.set_index('Date', inplace=True)
# Out:
# 112331

# %%
crimedf
# Out:
#             IncidntNum        Category                         Descript  \
# Date
# 2015-09-20   150827188    NON-CRIMINAL     AIDED CASE, MENTAL DISTURBED
# 2015-09-20   150827213         ASSAULT      INFLICT INJURY ON COHABITEE
# 2015-09-20   150827213         ASSAULT  ATTEMPTED HOMICIDE WITH A KNIFE
# 2015-09-20   150827213         ASSAULT           CHILD ABUSE (PHYSICAL)
# 2015-09-20   150827213         ASSAULT              MAYHEM WITH A KNIFE
# ...                ...             ...                              ...
# 2015-01-02   150007653           FRAUD     CREDIT CARD, THEFT BY USE OF
# 2015-01-02   150008457    NON-CRIMINAL                    LOST PROPERTY
# 2015-01-02   150005538  OTHER OFFENSES                TRAFFIC VIOLATION
# 2015-01-02   150005306    NON-CRIMINAL                    LOST PROPERTY
# 2015-01-02   150042029    NON-CRIMINAL     DEATH REPORT, NATURAL CAUSES
#
#            DayOfWeek   Time  PdDistrict      Resolution  \
# Date
# 2015-09-20    Sunday  23:54    RICHMOND       UNFOUNDED
# 2015-09-20    Sunday  23:45   INGLESIDE  ARREST, BOOKED
# 2015-09-20    Sunday  23:45   INGLESIDE  ARREST, BOOKED
# 2015-09-20    Sunday  23:45   INGLESIDE  ARREST, BOOKED
# 2015-09-20    Sunday  23:45   INGLESIDE  ARREST, BOOKED
# ...              ...    ...         ...             ...
# 2015-01-02    Friday  00:01  TENDERLOIN            NONE
# 2015-01-02    Friday  00:01        PARK            NONE
# 2015-01-02    Friday  00:01     MISSION  ARREST, BOOKED
# 2015-01-02    Friday  00:01     CENTRAL            NONE
# 2015-01-02    Friday  00:01    NORTHERN            NONE
#
#                              Address           X          Y  \
# Date
# 2015-09-20  3000 Block of CLEMENT ST -122.491851  37.781756
# 2015-09-20     100 Block of LOEHR ST -122.413676  37.712617
# 2015-09-20     100 Block of LOEHR ST -122.413676  37.712617
# 2015-09-20     100 Block of LOEHR ST -122.413676  37.712617
# 2015-09-20     100 Block of LOEHR ST -122.413676  37.712617
# ...                              ...         ...        ...
# 2015-01-02      400 Block of EDDY ST -122.415067  37.783563
# 2015-01-02     3600 Block of 16TH ST -122.434221  37.764224
# 2015-01-02   900 Block of POTRERO AV -122.406870  37.757290
# 2015-01-02   700 Block of VALLEJO ST -122.409792  37.798508
# 2015-01-02  2700 Block of LOMBARD ST -122.446662  37.798595
#
#                                          Location
# Date
# 2015-09-20  (37.7817557255921, -122.491851328976)
# 2015-09-20  (37.7126165766239, -122.413676487435)
# 2015-09-20  (37.7126165766239, -122.413676487435)
# 2015-09-20  (37.7126165766239, -122.413676487435)
# 2015-09-20  (37.7126165766239, -122.413676487435)
# ...                                           ...
# 2015-01-02   (37.7835634796332, -122.41506687647)
# 2015-01-02  (37.7642237070482, -122.434221184718)
# 2015-01-02  (37.7572895904578, -122.406870402082)
# 2015-01-02  (37.7985083480435, -122.409791662293)
# 2015-01-02  (37.7985952787295, -122.446662025856)
#
# [112331 rows x 11 columns]

# %% [markdown]
# Draw a timeseries plot to visualize number of crimes for each day.

# %%
# ANSWER
crimedf_crimeonly = crimedf[(crimedf["Category"] != "NON-CRIMINAL") & (crimedf["Category"] != "OTHER OFFENSES")]
grouped = crimedf_crimeonly.groupby(crimedf_crimeonly.index)
group_length = grouped.size()

# %%
plt.figure(figsize=(15, 10))
plt.plot(group_length.index, group_length.values, marker='.', markersize=10)
plt.grid(True)
plt.tight_layout()

# %% [markdown]
# Using folium we can easily create a map. As it's SF data, by default we are using SF location.

# %%
def generateBaseMap(default_location=[37.76, -122.45], default_zoom_start=12):
    '''
    Create a base map
    '''
    base_map = folium.Map(
        location = default_location
        , control_scale = True
        , zoom_start = default_zoom_start
    )

    return base_map

# %%
base_map = generateBaseMap(default_location=[37.76, -122.45])
display(base_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f92b5a1533bc1e3f4c1abcbac62f85c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f92b5a1533bc1e3f4c1abcbac62f85c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f92b5a1533bc1e3f4c1abcbac62f85c1 = L.map(
#                 &quot;map_f92b5a1533bc1e3f4c1abcbac62f85c1&quot;,
#                 {
#                     center: [37.76, -122.45],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f92b5a1533bc1e3f4c1abcbac62f85c1);
#
#
#
#
#
#             var tile_layer_13657c9a34a478cb73755c73494bd76b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f92b5a1533bc1e3f4c1abcbac62f85c1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Add a marker in the map using `Folium.Marker` for first 100 rows of the dataset.

# %%
crimedf100=crimedf.iloc[:100,:]

def AddMarker(row):
    folium.Marker(
        location=[row["Y"], row["X"]],
        popup=row["Address"]
    ).add_to(base_map)

for index, row in crimedf100.iterrows():
    AddMarker(row)
    
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d88e34415a15a86fb97bf7edb28f040 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d88e34415a15a86fb97bf7edb28f040&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7d88e34415a15a86fb97bf7edb28f040 = L.map(
#                 &quot;map_7d88e34415a15a86fb97bf7edb28f040&quot;,
#                 {
#                     center: [37.76, -122.45],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7d88e34415a15a86fb97bf7edb28f040);
#
#
#
#
#
#             var tile_layer_345a4d5a268f0e8026d609f09b2d5045 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7d88e34415a15a86fb97bf7edb28f040);
#
#
#             var marker_fcd37e6bba6c71977f882c59497e32fd = L.marker(
#                 [37.7749, -122.4194],
#                 {}
#             ).addTo(map_7d88e34415a15a86fb97bf7edb28f040);
#
#
#         var popup_480286a59ac0c10aff02d1c273cc0cd3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b8520ce0ebc695479d67585051e1ab94 = $(`&lt;div id=&quot;html_b8520ce0ebc695479d67585051e1ab94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Francisco&lt;/div&gt;`)[0];
#                 popup_480286a59ac0c10aff02d1c273cc0cd3.setContent(html_b8520ce0ebc695479d67585051e1ab94);
#
#
#
#         marker_fcd37e6bba6c71977f882c59497e32fd.bindPopup(popup_480286a59ac0c10aff02d1c273cc0cd3)
#         ;
#
#
#
#
#             var marker_8c379845926df403e59bb13c5a22c6b4 = L.marker(
#                 [37.7749, -122.4194],
#                 {}
#             ).addTo(map_7d88e34415a15a86fb97bf7edb28f040);
#
#
#         var popup_1bdf8205f27df8caa79b0fb1377438e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_20b2fd43ac4231f4dcd84f45af908d71 = $(`&lt;div id=&quot;html_20b2fd43ac4231f4dcd84f45af908d71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Francisco&lt;/div&gt;`)[0];
#                 popup_1bdf8205f27df8caa79b0fb1377438e1.setContent(html_20b2fd43ac4231f4dcd84f45af908d71);
#
#
#
#         marker_8c379845926df403e59bb13c5a22c6b4.bindPopup(popup_1bdf8205f27df8caa79b0fb1377438e1)
#         ;
#
#
#
#
#             var marker_5a7b1b77ae6ad01c14b1e825eef9d4da = L.marker(
#                 [-122.491851328976, 37.7817557255921],
#                 {}
#             ).addTo(map_7d88e34415a15a86fb97bf7edb28f040);
#
#
#         var popup_a5970f0102576dcaf316186a9bd6569c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e994060f797eb552d10fc3cb7609a1d = $(`&lt;div id=&quot;html_8e994060f797eb552d10fc3cb7609a1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3000 Block of CLEMENT ST&lt;/div&gt;`)[0];
#                 popup_a5970f0102576dcaf316186a9bd6569c.setContent(html_8e994060f797eb552d10fc3cb7609a1d);
#
#
#
#         marker_5a7b1b77ae6ad01c14b1e825eef9d4da.bindPopup(popup_a5970f0102576dcaf316186a9bd6569c)
#         ;
#
#
#
#
#             var marker_8da1e6cc8ba72a8f7585244eaa94f71a = L.marker(
#                 [-122.413676487435, 37.7126165766239],
#                 {}
#             ).addTo(map_7d88e34415a15a86fb97bf7edb28f040);
#
#
#         var popup_d47c33a7797a9c39c3c05b730e3685ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c64a246aa9c8e2ea7148ff39c1b847d4 = $(`&lt;div id=&quot;html_c64a246aa9c8e2ea7148ff39c1b847d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;100 Block of LOEHR ST&lt;/div&gt;`)[0];
#                 popup_d47c33a7797a9c39c3c05b730e3685ba.setContent(html_c64a246aa9c8e2ea7148ff39c1b847d4);
#
#
#
#         marker_8da1e6cc8ba72a8f7585244eaa94f71a.bindPopup(popup_d47c33a7797a9c39c3c05b730e3685ba)
#         ;
#
#
#
#
#             var marker_d9a2338b88c02986cef6ebb5e8379a7a = L.marker(
#                 [-122.413676487435, 37.7126165766239],
#                 {}
#             ).addTo(map_7d88e34415a15a86fb97bf7edb28f040);
#
#
#         var popup_8ed8403d86ce1d992acccab1a9ee7561 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b44e55b8044c81b718738251cc80968e = $(`&lt;div id=&quot;html_b44e55b8044c81b718738251cc80968e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;100 Block of LOEHR ST&lt;/div&gt;`)[0];
#                 popup_8ed8403d86ce1d992acccab1a9ee7561.setContent(html_b44e55b8044c81b718738251cc80968e);
#
#
#
#         marker_d9a2338b88c02986cef6ebb5e8379a7a.bindPopup(popup_8ed8403d86ce1d992acccab1a9ee7561)
#         ;

# %% [markdown]
# Add a cricle in the map using `Folium Circle` for first 100 rows of the dataset.

# %%
# ANSWER
def AddCircle(row):
    folium.Circle(
        location=[row["Y"], row["X"]],
        radius=1000,
        color='red',
        fill=True,
        fill_color='red'
    ).add_to(base_map)

for index, row in crimedf100.iterrows():
    AddCircle(row)
    
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d88e34415a15a86fb97bf7edb28f040 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d88e34415a15a86fb97bf7edb28f040&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7d88e34415a15a86fb97bf7edb28f040 = L.map(
#                 &quot;map_7d88e34415a15a86fb97bf7edb28f040&quot;,
#                 {
#                     center: [37.76, -122.45],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7d88e34415a15a86fb97bf7edb28f040);
#
#
#
#
#
#             var tile_layer_345a4d5a268f0e8026d609f09b2d5045 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7d88e34415a15a86fb97bf7edb28f040);
#
#
#             var marker_fcd37e6bba6c71977f882c59497e32fd = L.marker(
#                 [37.7749, -122.4194],
#                 {}
#             ).addTo(map_7d88e34415a15a86fb97bf7edb28f040);
#
#
#         var popup_480286a59ac0c10aff02d1c273cc0cd3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b8520ce0ebc695479d67585051e1ab94 = $(`&lt;div id=&quot;html_b8520ce0ebc695479d67585051e1ab94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Francisco&lt;/div&gt;`)[0];
#                 popup_480286a59ac0c10aff02d1c273cc0cd3.setContent(html_b8520ce0ebc695479d67585051e1ab94);
#
#
#
#         marker_fcd37e6bba6c71977f882c59497e32fd.bindPopup(popup_480286a59ac0c10aff02d1c273cc0cd3)
#         ;
#
#
#
#
#             var marker_8c379845926df403e59bb13c5a22c6b4 = L.marker(
#                 [37.7749, -122.4194],
#                 {}
#             ).addTo(map_7d88e34415a15a86fb97bf7edb28f040);
#
#
#         var popup_1bdf8205f27df8caa79b0fb1377438e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_20b2fd43ac4231f4dcd84f45af908d71 = $(`&lt;div id=&quot;html_20b2fd43ac4231f4dcd84f45af908d71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;San Francisco&lt;/div&gt;`)[0];
#                 popup_1bdf8205f27df8caa79b0fb1377438e1.setContent(html_20b2fd43ac4231f4dcd84f45af908d71);
#
#
#
#         marker_8c379845926df403e59bb13c5a22c6b4.bindPopup(popup_1bdf8205f27df8caa79b0fb1377438e1)
#         ;
#
#
#
#
#             var marker_5a7b1b77ae6ad01c14b1e825eef9d4da = L.marker(
#                 [-122.491851328976, 37.7817557255921],
#                 {}
#             ).addTo(map_7d88e34415a15a86fb97bf7edb28f040);
#
#
#         var popup_a5970f0102576dcaf316186a9bd6569c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e994060f797eb552d10fc3cb7609a1d = $(`&lt;div id=&quot;html_8e994060f797eb552d10fc3cb7609a1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3000 Block of CLEMENT ST&lt;/div&gt;`)[0];
#                 popup_a5970f0102576dcaf316186a9bd6569c.setContent(html_8e994060f797eb552d10fc3cb7609a1d);
#
#
#
#         marker_5a7b1b77ae6ad01c14b1e825eef9d4da.bindPopup(popup_a5970f0102576dcaf316186a9bd6569c)
#         ;
#
#
#
#
#             var marker_8da1e6cc8ba72a8f7585244eaa94f71a = L.marker(
#                 [-122.413676487435, 37.7126165766239],
#                 {}
#             ).addTo(map_7d88e34415a15a86fb97bf7edb28f040);
#
#
#         var popup_d47c33a7797a9c39c3c05b730e3685ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c64a246aa9c8e2ea7148ff39c1b847d4 = $(`&lt;div id=&quot;html_c64a246aa9c8e2ea7148ff39c1b847d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;100 Block of LOEHR ST&lt;/div&gt;`)[0];
#                 popup_d47c33a7797a9c39c3c05b730e3685ba.setContent(html_c64a246aa9c8e2ea7148ff39c1b847d4);
#
#
#
#         marker_8da1e6cc8ba72a8f7585244eaa94f71a.bindPopup(popup_d47c33a7797a9c39c3c05b730e3685ba)
#         ;
#
#
#
#
#             var marker_d9a2338b88c02986cef6ebb5e8379a7a = L.marker(
#                 [-122.413676487435, 37.7126165766239],
#                 {}
#             ).addTo(map_7d88e34415a15a86fb97bf7edb28f040);
#
#
#         var popup_8ed8403d86ce1d992acccab1a9ee7561 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b44e55b8044c81b718738251cc80968e = $(`&lt;div id=&quot;html_b44e55b8044c81b718738251cc80968e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;100 Block of LOEHR ST&lt;/div&gt;`)[0];
#                 popup_8ed8403d86ce1d992acccab1a9ee7561.setContent(html_b44e55b8044c81b718738251cc80968e);
#
#
#
#         marker_d9a2338b88c02986cef6ebb5e8379a7a.bindPopup(popup_8ed8403d86ce1d992acccab1a9ee7561)
#         ;

# %% [markdown]
# [BONUS] Create a heatmap of the incident happened in SF.

# %%
sns.heatmap(crimedf.corr(numeric_only=True))
# Out:
# <Axes: >

# %% [markdown]
# **HOMEWORK** Explore Folium as much as you can.
#
# **HOMEWORK** Explore GeoPandas

# %% [markdown]
# # More Resources
#
# <a name="histfootnote">1</a>: [Histogram](https://en.wikipedia.org/wiki/Histogram)
#
# The matplotlib users' guide is at http://pageperso.lif.univ-mrs.fr/~francois.denis/IAAM1/Matplotlib.pdf.

# %% [markdown]
# For visualisation ideas and code see https://python-graph-gallery.com/:

# %% [markdown]
# 2: GeoPandas
#
# > The goal of GeoPandas is to make working with geospatial data in python easier. It combines the capabilities of pandas and shapely, providing geospatial operations in pandas and a high-level interface to multiple geometries to shapely. GeoPandas enables you to easily do operations in python that would otherwise require a spatial database such as PostGIS.
#
# [GeoPandas 0.13.2](http://geopandas.org/index.html#)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2023 Institute of Data
#
#
# ---
#
#
#
# ---
